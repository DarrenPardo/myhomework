# %%
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# # Store CSV into DataFrame

# %%
csv_file = "Resources/raw_state_automation_data_1.csv"
raw_state_automation_data_df = pd.read_csv(csv_file)
raw_state_automation_data_df.head()
# Out:
#        SOC                                        Occupation  Probability  \
# 0  11-1011                                  Chief Executives        0.015
# 1  11-1021                   General and Operations Managers        0.160
# 2  11-3061                               Purchasing Managers        0.030
# 3  17-3013                               Mechanical Drafters        0.680
# 4  17-3021  Aerospace Engineering and Operations Technicians        0.480
#
#    Alabama  Alaska  Arizona  Arkansas  California  Colorado  Connecticut  ...  \
# 0     1030     760     5750      2710       31150       880         1410  ...
# 1    26930    6490    43300     20680      261780     41540        33280  ...
# 2      950     130     1780       510        8460       760         1360  ...
# 3      590       0      750       240        3900       880         1900  ...
# 4      190       0      570        60        2490       310          150  ...
#
#    South_Dakota  Tennessee   Texas   Utah  Vermont  Virginia  Washington  \
# 0           560       5460    5890   3650      280      6320        5910
# 1          3730      44400  168610  36200     2760     52380       43760
# 2            50       2000    5030    450      150      2480        2010
# 3           170       1240    4900    650       90      2020        2250
# 4             0          0    1200    130        0       160           0
#
#    West_Virginia  Wisconsin  Wyoming
# 0            980       3740      160
# 1          10200      32350     4840
# 2             80       1290       40
# 3            150       2730       80
# 4              0          0        0
#
# [5 rows x 54 columns]

# %% [markdown]
# # Create new data with select columns

# %%
state_automation_data_df = raw_state_automation_data_df[['SOC', 'Occupation', 'Probability']].copy()
state_automation_data_df.head()
# Out:
#        SOC                                        Occupation  Probability
# 0  11-1011                                  Chief Executives        0.015
# 1  11-1021                   General and Operations Managers        0.160
# 2  11-3061                               Purchasing Managers        0.030
# 3  17-3013                               Mechanical Drafters        0.680
# 4  17-3021  Aerospace Engineering and Operations Technicians        0.480

# %%
csv_file = "Resources/occupational_employment_statistics_1.csv"
occupational_employment_statistics_data_df = pd.read_csv(csv_file)
occupational_employment_statistics_data_df.head()
# Out:
#    Area_Type  Area                Area_Name      SOC  \
# 0         10     1           Capital Region  11-2031
# 1         10     6     Mohawk Valley Region  15-1111
# 2         10    10  Western New York Region  39-4031
# 3         10     8     North Country Region  39-9099
# 4         10    10  Western New York Region  33-3041
#
#                                 Occupational_Title  Employment  Mean_Wage  \
# 0        Public Relations and Fundraising Managers       400.0     103400
# 1     Computer and Information Research Scientists       120.0     103680
# 2   Morticians, Undertakers, and Funeral Directors         NaN      62910
# 3     Personal Care and Service Workers, All Other         NaN      30210
# 4                      Parking Enforcement Workers         NaN      35380
#
#    Median_Wage  Entry_Wage  Experienced_Wage
# 0      89550.0     55480.0          127360.0
# 1     102530.0     79840.0          115610.0
# 2      64990.0     45420.0           71660.0
# 3      30430.0     24730.0           32950.0
# 4      35320.0     29380.0           38390.0

# %%
employment_wage_df = occupational_employment_statistics_data_df[['SOC', 'Occupational_Title', 'Mean_Wage', 'Median_Wage', 'Entry_Wage', 'Experienced_Wage']].copy()                                                                                                                  
employment_wage_df.head()
# Out:
#        SOC                               Occupational_Title  Mean_Wage  \
# 0  11-2031        Public Relations and Fundraising Managers     103400
# 1  15-1111     Computer and Information Research Scientists     103680
# 2  39-4031   Morticians, Undertakers, and Funeral Directors      62910
# 3  39-9099     Personal Care and Service Workers, All Other      30210
# 4  33-3041                      Parking Enforcement Workers      35380
#
#    Median_Wage  Entry_Wage  Experienced_Wage
# 0      89550.0     55480.0          127360.0
# 1     102530.0     79840.0          115610.0
# 2      64990.0     45420.0           71660.0
# 3      30430.0     24730.0           32950.0
# 4      35320.0     29380.0           38390.0

# %%
rds_connection_string = "postgres:Darren2019@localhost:5432/occupation_automation_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# ['automation_probability', 'occupational_employment_statistics']

# %% [markdown]
# # Load DataFrames into Database

# %%
state_automation_data_df.to_sql(name='automation_probability', con=engine, if_exists='append', index=True)
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1223                     self.dialect.do_executemany(
# -> 1224                         cursor, statement, parameters, context
#    1225                     )
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     724         else:
# --> 725             cursor.executemany(statement, parameters)
#     726
#
# UndefinedColumn: column "index" of relation "automation_probability" does not exist
# LINE 1: INSERT INTO automation_probability (index, "SOC", "Occupatio...
#                                             ^
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-12-6976447d2434> in <module>
# ----> 1 state_automation_data_df.to_sql(name='automation_probability', con=engine, if_exists='append', index=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2529         sql.to_sql(self, name, con, schema=schema, if_exists=if_exists,
#    2530                    index=index, index_label=index_label, chunksize=chunksize,
# -> 2531                    dtype=dtype, method=method)
#    2532
#    2533     def to_pickle(self, path, compression='infer',
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     458     pandas_sql.to_sql(frame, name, if_exists=if_exists, index=index,
#     459                       index_label=index_label, schema=schema,
# --> 460                       chunksize=chunksize, dtype=dtype, method=method)
#     461
#     462
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1172                          schema=schema, dtype=dtype)
#    1173         table.create()
# -> 1174         table.insert(chunksize, method=method)
#    1175         if (not name.isdigit() and not name.islower()):
#    1176             # check for potentially case sensitivity issues (GH7815)
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     684
#     685                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 686                 exec_insert(conn, keys, chunk_iter)
#     687
#     688     def _query_iterator(self, result, chunksize, columns, coerce_float=True,
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     597         """
#     598         data = [dict(zip(keys, row)) for row in data_iter]
# --> 599         conn.execute(self.table.insert(), data)
#     600
#     601     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#     986             raise exc.ObjectNotExecutableError(object_)
#     987         else:
# --> 988             return meth(self, multiparams, params)
#     989
#     990     def _execute_function(self, func, multiparams, params):
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     285     def _execute_on_connection(self, connection, multiparams, params):
#     286         if self.supports_execution:
# --> 287             return connection._execute_clauseelement(self, multiparams, params)
#     288         else:
#     289             raise exc.ObjectNotExecutableError(self)
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1105             distilled_params,
#    1106             compiled_sql,
# -> 1107             distilled_params,
#    1108         )
#    1109         if self._has_events or self.engine._has_events:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1246         except BaseException as e:
#    1247             self._handle_dbapi_exception(
# -> 1248                 e, statement, parameters, cursor, context
#    1249             )
#    1250
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1464                 util.raise_from_cause(newraise, exc_info)
#    1465             elif should_wrap:
# -> 1466                 util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1467             else:
#    1468                 util.reraise(*exc_info)
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     381     exc_type, exc_value, exc_tb = exc_info
#     382     cause = exc_value if exc_value is not exception else None
# --> 383     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     384
#     385
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     126             value.__cause__ = cause
#     127         if value.__traceback__ is not tb:
# --> 128             raise value.with_traceback(tb)
#     129         raise value
#     130
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1222                 if not evt_handled:
#    1223                     self.dialect.do_executemany(
# -> 1224                         cursor, statement, parameters, context
#    1225                     )
#    1226             elif not parameters and context.no_parameters:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     723             extras.execute_batch(cursor, statement, parameters)
#     724         else:
# --> 725             cursor.executemany(statement, parameters)
#     726
#     727     @util.memoized_instancemethod
#
# ProgrammingError: (psycopg2.errors.UndefinedColumn) column "index" of relation "automation_probability" does not exist
# LINE 1: INSERT INTO automation_probability (index, "SOC", "Occupatio...
#                                             ^
#
# [SQL: INSERT INTO automation_probability (index, "SOC", "Occupation", "Probability") VALUES (%(index)s, %(SOC)s, %(Occupation)s, %(Probability)s)]
# [parameters: ({'index': 0, 'SOC': '11-1011', 'Occupation': 'Chief Executives', 'Probability': 0.015}, {'index': 1, 'SOC': '11-1021', 'Occupation': 'General and Operations Managers', 'Probability': 0.16}, {'index': 2, 'SOC': '11-3061', 'Occupation': 'Purchasing Managers', 'Probability': 0.03}, {'index': 3, 'SOC': '17-3013', 'Occupation': 'Mechanical Drafters', 'Probability': 0.68}, {'index': 4, 'SOC': '17-3021', 'Occupation': 'Aerospace Engineering and Operations Technicians', 'Probability': 0.48}, {'index': 5, 'SOC': '17-3022', 'Occupation': 'Civil Engineering Technicians', 'Probability': 0.75}, {'index': 6, 'SOC': '17-3023', 'Occupation': 'Electrical and Electronics Engineering Technicians', 'Probability': 0.84}, {'index': 7, 'SOC': '17-3024', 'Occupation': 'Electro-Mechanical Technicians', 'Probability': 0.81}  ... displaying 10 of 702 total bound parameter sets ...  {'index': 700, 'SOC': '17-3011', 'Occupation': 'Architectural and Civil Drafters', 'Probability': 0.52}, {'index': 701, 'SOC': '17-3012', 'Occupation': 'Electrical and Electronics Drafters', 'Probability': 0.81})]
# (Background on this error at: http://sqlalche.me/e/f405)

# %%
employment_wage_df.to_sql(name='occupational_employment_statistics', con=engine, if_exists='append', index=True)
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1223                     self.dialect.do_executemany(
# -> 1224                         cursor, statement, parameters, context
#    1225                     )
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     724         else:
# --> 725             cursor.executemany(statement, parameters)
#     726
#
# UndefinedColumn: column "index" of relation "occupational_employment_statistics" does not exist
# LINE 1: INSERT INTO occupational_employment_statistics (index, "SOC"...
#                                                         ^
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-13-a2b90a624d94> in <module>
# ----> 1 employment_wage_df.to_sql(name='occupational_employment_statistics', con=engine, if_exists='append', index=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2529         sql.to_sql(self, name, con, schema=schema, if_exists=if_exists,
#    2530                    index=index, index_label=index_label, chunksize=chunksize,
# -> 2531                    dtype=dtype, method=method)
#    2532
#    2533     def to_pickle(self, path, compression='infer',
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     458     pandas_sql.to_sql(frame, name, if_exists=if_exists, index=index,
#     459                       index_label=index_label, schema=schema,
# --> 460                       chunksize=chunksize, dtype=dtype, method=method)
#     461
#     462
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1172                          schema=schema, dtype=dtype)
#    1173         table.create()
# -> 1174         table.insert(chunksize, method=method)
#    1175         if (not name.isdigit() and not name.islower()):
#    1176             # check for potentially case sensitivity issues (GH7815)
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     684
#     685                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 686                 exec_insert(conn, keys, chunk_iter)
#     687
#     688     def _query_iterator(self, result, chunksize, columns, coerce_float=True,
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     597         """
#     598         data = [dict(zip(keys, row)) for row in data_iter]
# --> 599         conn.execute(self.table.insert(), data)
#     600
#     601     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#     986             raise exc.ObjectNotExecutableError(object_)
#     987         else:
# --> 988             return meth(self, multiparams, params)
#     989
#     990     def _execute_function(self, func, multiparams, params):
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     285     def _execute_on_connection(self, connection, multiparams, params):
#     286         if self.supports_execution:
# --> 287             return connection._execute_clauseelement(self, multiparams, params)
#     288         else:
#     289             raise exc.ObjectNotExecutableError(self)
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1105             distilled_params,
#    1106             compiled_sql,
# -> 1107             distilled_params,
#    1108         )
#    1109         if self._has_events or self.engine._has_events:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1246         except BaseException as e:
#    1247             self._handle_dbapi_exception(
# -> 1248                 e, statement, parameters, cursor, context
#    1249             )
#    1250
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1464                 util.raise_from_cause(newraise, exc_info)
#    1465             elif should_wrap:
# -> 1466                 util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1467             else:
#    1468                 util.reraise(*exc_info)
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     381     exc_type, exc_value, exc_tb = exc_info
#     382     cause = exc_value if exc_value is not exception else None
# --> 383     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     384
#     385
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     126             value.__cause__ = cause
#     127         if value.__traceback__ is not tb:
# --> 128             raise value.with_traceback(tb)
#     129         raise value
#     130
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1222                 if not evt_handled:
#    1223                     self.dialect.do_executemany(
# -> 1224                         cursor, statement, parameters, context
#    1225                     )
#    1226             elif not parameters and context.no_parameters:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     723             extras.execute_batch(cursor, statement, parameters)
#     724         else:
# --> 725             cursor.executemany(statement, parameters)
#     726
#     727     @util.memoized_instancemethod
#
# ProgrammingError: (psycopg2.errors.UndefinedColumn) column "index" of relation "occupational_employment_statistics" does not exist
# LINE 1: INSERT INTO occupational_employment_statistics (index, "SOC"...
#                                                         ^
#
# [SQL: INSERT INTO occupational_employment_statistics (index, "SOC", "Occupational_Title", "Mean_Wage", "Median_Wage", "Entry_Wage", "Experienced_Wage") VALUES (%(index)s, %(SOC)s, %(Occupational_Title)s, %(Mean_Wage)s, %(Median_Wage)s, %(Entry_Wage)s, %(Experienced_Wage)s)]
# [parameters: ({'index': 0, 'SOC': '11-2031', 'Occupational_Title': 'Public Relations and Fundraising Managers', 'Mean_Wage': 103400, 'Median_Wage': 89550.0, 'Entry_Wage': 55480.0, 'Experienced_Wage': 127360.0}, {'index': 1, 'SOC': '15-1111', 'Occupational_Title': 'Computer and Information Research Scientists', 'Mean_Wage': 103680, 'Median_Wage': 102530.0, 'Entry_Wage': 79840.0, 'Experienced_Wage': 115610.0}, {'index': 2, 'SOC': '39-4031', 'Occupational_Title': ' Morticians, Undertakers, and Funeral Directors', 'Mean_Wage': 62910, 'Median_Wage': 64990.0, 'Entry_Wage': 45420.0, 'Experienced_Wage': 71660.0}, {'index': 3, 'SOC': '39-9099', 'Occupational_Title': ' Personal Care and Service Workers, All Other', 'Mean_Wage': 30210, 'Median_Wage': 30430.0, 'Entry_Wage': 24730.0, 'Experienced_Wage': 32950.0}, {'index': 4, 'SOC': '33-3041', 'Occupational_Title': 'Parking Enforcement Workers', 'Mean_Wage': 35380, 'Median_Wage': 35320.0, 'Entry_Wage': 29380.0, 'Experienced_Wage': 38390.0}, {'index': 5, 'SOC': '25-2054', 'Occupational_Title': ' Special Education Teachers, Secondary School', 'Mean_Wage': 97580, 'Median_Wage': 101600.0, 'Entry_Wage': 62940.0, 'Experienced_Wage': 114900.0}, {'index': 6, 'SOC': '21-2011', 'Occupational_Title': 'Clergy', 'Mean_Wage': 42070, 'Median_Wage': 36700.0, 'Entry_Wage': 28240.0, 'Experienced_Wage': 48990.0}, {'index': 7, 'SOC': '45-0000', 'Occupational_Title': 'Farming, Fishing, and Forestry Occupations', 'Mean_Wage': 38410, 'Median_Wage': 36070.0, 'Entry_Wage': 24990.0, 'Experienced_Wage': 45120.0}  ... displaying 10 of 5000 total bound parameter sets ...  {'index': 4998, 'SOC': '53-7081', 'Occupational_Title': 'Refuse and Recyclable Material Collectors', 'Mean_Wage': 34260, 'Median_Wage': 32460.0, 'Entry_Wage': 24130.0, 'Experienced_Wage': 39320.0}, {'index': 4999, 'SOC': '11-9021', 'Occupational_Title': 'Construction Managers', 'Mean_Wage': 89480, 'Median_Wage': 85100.0, 'Entry_Wage': 61030.0, 'Experienced_Wage': 103710.0})]
# (Background on this error at: http://sqlalche.me/e/f405)

# %% [markdown]
# # Confirm data has been added by querying the table

# %%
pd.read_sql_query('select * from automation_probability', con=engine).head()
# Out:
# Empty DataFrame
# Columns: [soc, occupation, probability]
# Index: []

# %%
pd.read_sql_query('select * from occupational_employment_statistics', con=engine).head()
# Out:
# Empty DataFrame
# Columns: [soc, occupational_title, mean_wage, median_wage, entry_wage, experienced_wage]
# Index: []
